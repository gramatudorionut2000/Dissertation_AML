# %%
import pandas as pd

df=pd.read_csv('D:\Dizertatie\Money_Laundering_project\media\inference\graph_preprocessor.csv')
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\D'
# <>:3: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Superuser\AppData\Local\Temp\ipykernel_3152\55829926.py:3: SyntaxWarning: invalid escape sequence '\D'
#   df=pd.read_csv('D:\Dizertatie\Money_Laundering_project\media\inference\graph_preprocessor.csv')

# %%
df.tail()
# Out:
#           EdgeID  from_id   to_id  Timestamp  feature_0  feature_1  feature_2  \
# 5078340  5078340    65000   75723  1515730.0    3749.14        0.0    3749.14
# 5078341  5078341    65000   65000  1520290.0    2091.95        0.0    1785.27
# 5078342  5078342    65000  201521  1520290.0    1785.27        1.0    1785.27
# 5078343  5078343    65000  275383  1526290.0    2154.54        0.0    2154.54
# 5078344  5078344    65000  206627  1538290.0    5448.55        0.0    5448.55
#
#          feature_3  time_window  vertex_stats_time_window  ...  \
# 5078340        0.0          4.0                       1.0  ...
# 5078341        1.0          4.0                       0.0  ...
# 5078342        1.0          4.0                       1.0  ...
# 5078343        0.0          4.0                       1.0  ...
# 5078344        0.0          4.0                       1.0  ...
#
#          dest_skew_col3_out  dest_kurtosis_col3_out  dest_fan_in  dest_deg_in  \
# ...

# %%
import pandas as pd
df2=pd.read_csv('D:\Dizertatie\Money_Laundering_project\media\inference\\GFP_transactions.csv')
df2.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Superuser\AppData\Local\Temp\ipykernel_1264\326572054.py:2: SyntaxWarning: invalid escape sequence '\D'
#   df2=pd.read_csv('D:\Dizertatie\Money_Laundering_project\media\inference\\GFP_transactions.csv')
#    EdgeID  from_id  to_id  Timestamp  Amount Sent  Sent Currency  \
# 0      23       26     26    10810.0     21163.90            0.0
# 1      22       25     25    10810.0    560045.98            0.0
# 2      21       23     24    10810.0     65669.07            0.0
# 3      20       22     22    10810.0    145397.31            0.0
# 4      19       21     21    10810.0        21.53            0.0
#
#    Amount Received  Received Currency  Payment Format  Is Laundering  ...  \
# 0         21163.90                0.0             0.0            0.0  ...
# 1        560045.98                0.0             0.0            0.0  ...
# ...

# %%
df2['dest_fan_in']
# Out:
# 0           2.0
# 1           3.0
# 2           4.0
# 3           3.0
# 4           2.0
#            ...
# 5078340     4.0
# 5078341    12.0
# 5078342     2.0
# 5078343     4.0
# 5078344     6.0
# Name: dest_fan_in, Length: 5078345, dtype: float64

# %%
renamed_df = df.rename(columns={
    'feature_0': 'Amount Sent',
    'feature_1': 'Sent Currency',
    'feature_2': 'Amount Received',
    'feature_3': 'Received Currency',
    'time_window': 'Payment Format',
    'vertex_stats_time_window': 'Is Laundering',
})

renamed_df.to_csv('renamed_dataframe.csv', index=False)

# %%
renamed_df.head()
# Out:
#    EdgeID  from_id  to_id  Timestamp  Amount Sent  Sent Currency  \
# 0      23       26     26    10810.0     21163.90            0.0
# 1      22       25     25    10810.0    560045.98            0.0
# 2      21       23     24    10810.0     65669.07            0.0
# 3      20       22     22    10810.0    145397.31            0.0
# 4      19       21     21    10810.0        21.53            0.0
#
#    Amount Received  Received Currency  Payment Format  Is Laundering  ...  \
# 0         21163.90                0.0             0.0            0.0  ...
# 1        560045.98                0.0             0.0            0.0  ...
# 2         65669.07                0.0             1.0            0.0  ...
# 3        145397.31                0.0             0.0            0.0  ...
# 4            21.53                0.0             0.0            0.0  ...
#
#    dest_skew_col3_out  dest_kurtosis_col3_out  dest_fan_in  dest_deg_in  \
# ...
